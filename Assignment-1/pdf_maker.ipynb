# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# texlive is already the newest version (2021.20220204-1).
# texlive-latex-extra is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# ...

# %%
# !jupyter nbconvert --to html "/content/drive/Othercomputers/astRo/SIT/TY - S1/NLP/Assignmennts/ass 1/NLP.Assignment.1.Jainil.Patel.21070126039.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/Othercomputers/astRo/SIT/TY - S1/NLP/Assignmennts/ass 1/NLP.Assignment.1.Jainil.Patel.21070126039.ipynb to html
# [NbConvertApp] Writing 787320 bytes to /content/drive/Othercomputers/astRo/SIT/TY - S1/NLP/Assignmennts/ass 1/NLP.Assignment.1.Jainil.Patel.21070126039.html

# %%
# !jupyter nbconvert --to PDF "/content/drive/Othercomputers/astRo/SIT/TY - S1/NLP/Assignmennts/ass 1/NLP.Assignment.1.Jainil.Patel.21070126039.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/Othercomputers/astRo/SIT/TY - S1/NLP/Assignmennts/ass 1/NLP.Assignment.1.Jainil.Patel.21070126039.ipynb to PDF
# [NbConvertApp] Support files will be in NLP.Assignment.1.Jainil.Patel.21070126039_files/
# [NbConvertApp] Making directory ./NLP.Assignment.1.Jainil.Patel.21070126039_files
# [NbConvertApp] Making directory ./NLP.Assignment.1.Jainil.Patel.21070126039_files
# [NbConvertApp] Writing 86708 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 159786 bytes to /content/drive/Othercomputers/astRo/SIT/TY - S1/NLP/Assignmennts/ass 1/NLP.Assignment.1.Jainil.Patel.21070126039.pdf
